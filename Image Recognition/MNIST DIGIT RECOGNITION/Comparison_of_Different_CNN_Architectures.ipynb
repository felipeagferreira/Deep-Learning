# %% [markdown]
# https://www.kaggle.com/cdeotte/how-to-choose-cnn-architecture-mnist

# %%
# Import modules
# Add modules as needed
from sklearn.datasets import fetch_openml
import numpy as np

# For windows laptops add following 2 lines:
# import matplotlib
# matplotlib.use('agg')

import matplotlib.pyplot as plt

import tensorflow.keras as keras

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
print('Shape of X_train:', X_train.shape, '\n', 'Shape of y_train:', y_train.shape)
'\n'
'\n'
print('Shape of X_test:', X_test.shape, '\n', 'Shape of y_test:', y_test.shape)
# Out:
# Shape of X_train: (60000, 28, 28)
#  Shape of y_train: (60000,)
# Shape of X_test: (10000, 28, 28)
#  Shape of y_test: (10000,)

# %%
print('Type of X_train:', type(X_train), '\n', 'Type of y_train:', type(y_train))
# Out:
# Type of X_train: <class 'numpy.ndarray'>
#  Type of y_train: <class 'numpy.ndarray'>

# %%
print('Type of X_test:', type(X_test), '\n', 'Type of y_test:', type(y_test))
# Out:
# Type of X_test: <class 'numpy.ndarray'>
#  Type of y_test: <class 'numpy.ndarray'>

# %%
6/7
# Out:
# 0.8571428571428571

# %% [markdown]
# ### **The input shape that a CNN accepts should be in a specific format. If you are using Tensorflow, the format should be (batch, height, width, channels). If you are using Theano, the format should be (batch, channels, height, width).**

# %%
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test  = X_test.reshape(X_test.shape[0], 28, 28, 1)

# %%
X_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
# When loading from "mnist.load_data()", we have to convert its type to float32
X_train = X_train.astype('float32')
X_train = X_train/255

X_test = X_test.astype('float32')
X_test = X_test/255

# %%
from keras.utils import to_categorical
number_of_classes = 10

y_train = to_categorical(y_train, number_of_classes)
y_test  = to_categorical(y_test,  number_of_classes)

# %% [markdown]
# ## **MODEL 1 :          784 - [24C5-P2] - 256 - 10**

# %% [markdown]
# This model has a convolution layer with 24 feature maps using a 5x5 filter and stride 1 PLUS a max pooling using 2x2 filter and stride 2.
# Then it has a fully connected dense layer with 256 units together with a final output dense layer with 10 units.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten

from keras.layers import Conv2D, MaxPooling2D

# %%
# define cnn model1

model1 = Sequential()
model1.add(Conv2D(24, (5, 5), padding='same', activation='relu', input_shape=(28, 28, 1)))
model1.add(MaxPooling2D((2, 2)))
  
model1.add(Flatten())                       # Talvez isso não seja necessário com o fetch_openml
model1.add(Dense(256, activation='relu'))
model1.add(Dense(10, activation='softmax'))

# %%
# Compile the model
model1.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model1.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 24)        624
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 24)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4704)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               1204480
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,207,674
# Trainable params: 1,207,674
# Non-trainable params: 0
# _________________________________________________________________

# %%
14*14*24
# Out:
# 4704

# %%
1204480/256
# Out:
# 4705.0

# %%
# Fit the model
history = model1.fit(X_train, y_train, batch_size=64, epochs=12)
# Out:
# Epoch 1/12
# 938/938 [==============================] - 60s 63ms/step - loss: 0.3188 - accuracy: 0.9050
# Epoch 2/12
# 938/938 [==============================] - 57s 61ms/step - loss: 0.0484 - accuracy: 0.9849
# Epoch 3/12
# 938/938 [==============================] - 57s 61ms/step - loss: 0.0269 - accuracy: 0.9916
# Epoch 4/12
# 938/938 [==============================] - 57s 61ms/step - loss: 0.0187 - accuracy: 0.9939
# Epoch 5/12
# 938/938 [==============================] - 58s 61ms/step - loss: 0.0131 - accuracy: 0.9963
# Epoch 6/12
# 938/938 [==============================] - 56s 59ms/step - loss: 0.0101 - accuracy: 0.9966
# Epoch 7/12
# 938/938 [==============================] - 58s 62ms/step - loss: 0.0074 - accuracy: 0.9975
# Epoch 8/12
# 938/938 [==============================] - 55s 58ms/step - loss: 0.0054 - accuracy: 0.9982
# Epoch 9/12
# 938/938 [==============================] - 52s 55ms/step - loss: 0.0061 - accuracy: 0.9981
# Epoch 10/12
# 938/938 [==============================] - 47s 51ms/step - loss: 0.0045 - accuracy: 0.9988
# Epoch 11/12
# 938/938 [==============================] - 48s 52ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 12/12
# 938/938 [==============================] - 47s 50ms/step - loss: 0.0047 - accuracy: 0.9982

# %%
Test_loss = model1.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 0.0461 - accuracy: 0.9882

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 0.046124644577503204
# Test accuracy: 0.9882000088691711

# %% [markdown]
# #### **Not that possibly the level of overfitting can be reduced by using a dropout layer**

# %%
model1 = Sequential()
model1.add(Conv2D(24, (5, 5), padding='same', activation='relu', input_shape=(28, 28, 1)))
model1.add(MaxPooling2D((2, 2)))
model1.add(Dropout(0.2))
  
model1.add(Flatten())                       # Talvez isso não seja necessário com o fetch_openml
model1.add(Dense(256, activation='relu'))
model1.add(Dropout(0.2))
model1.add(Dense(10, activation='softmax'))

# %%
# Compile the model
model1.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model1.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 28, 28, 24)        624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 24)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 24)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4704)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               1204480
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,207,674
# Trainable params: 1,207,674
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
history = model1.fit(X_train, y_train, batch_size=64, epochs=12)
# Out:
# Epoch 1/12
# 938/938 [==============================] - 51s 54ms/step - loss: 0.3445 - accuracy: 0.8909
# Epoch 2/12
# 938/938 [==============================] - 46s 49ms/step - loss: 0.0624 - accuracy: 0.9811
# Epoch 3/12
# 938/938 [==============================] - 47s 50ms/step - loss: 0.0426 - accuracy: 0.9874
# Epoch 4/12
# 938/938 [==============================] - 46s 49ms/step - loss: 0.0314 - accuracy: 0.9896
# Epoch 5/12
# 938/938 [==============================] - 46s 49ms/step - loss: 0.0237 - accuracy: 0.9920
# Epoch 6/12
# 938/938 [==============================] - 48s 51ms/step - loss: 0.0205 - accuracy: 0.9929
# Epoch 7/12
# 938/938 [==============================] - 47s 50ms/step - loss: 0.0168 - accuracy: 0.9942
# Epoch 8/12
# 938/938 [==============================] - 53s 56ms/step - loss: 0.0139 - accuracy: 0.9951
# Epoch 9/12
# 938/938 [==============================] - 48s 52ms/step - loss: 0.0114 - accuracy: 0.9961
# Epoch 10/12
# 938/938 [==============================] - 47s 50ms/step - loss: 0.0109 - accuracy: 0.9962
# Epoch 11/12
# 938/938 [==============================] - 47s 50ms/step - loss: 0.0102 - accuracy: 0.9963
# Epoch 12/12
# 938/938 [==============================] - 45s 48ms/step - loss: 0.0092 - accuracy: 0.9967

# %%
Test_loss = model1.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 4s 11ms/step - loss: 0.0321 - accuracy: 0.9907

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 0.0320826880633831
# Test accuracy: 0.9907000064849854

# %% [markdown]
# ## **784 - [24C5-P2] - [48C5-P2] - 256 - 10**

# %% [markdown]
# This model has a (convolution layer with 24 feature maps using a 5x5 filter and stride 1 together with a max pooling using 2x2 filter and stride 2) PLUS a (convolutional layer with 48 feature maps using a 5x5 filter and stride 1 together with a max pooling using 2x2 filter and stride 2). Then it has a fully connected dense layer with 256 units together with a final output dense layer with 10 units.

# %%
# define cnn model1

model2 = Sequential()
model2.add(Conv2D(24, (5, 5), padding='same', activation='relu', input_shape=(28, 28, 1)))
model2.add(MaxPooling2D((2, 2)))
model2.add(Dropout(0.2))

model2.add(Conv2D(48, (5, 5), padding='same', activation='relu'))
model2.add(MaxPooling2D((2, 2)))
model2.add(Dropout(0.2))
  
model2.add(Flatten())                       # Talvez isso não seja necessário com o fetch_openml
model2.add(Dense(256, activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(10, activation='softmax'))

# %%
# Compile the model
model2.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model2.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 28, 28, 24)        624
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 24)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 24)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 48)        28848
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 48)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 7, 48)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2352)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               602368
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 634,410
# Trainable params: 634,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
history = model2.fit(X_train, y_train, batch_size=64, epochs=12)
# Out:
# Epoch 1/12
# 938/938 [==============================] - 103s 110ms/step - loss: 0.3655 - accuracy: 0.8861
# Epoch 2/12
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0576 - accuracy: 0.9815
# Epoch 3/12
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0459 - accuracy: 0.9858
# Epoch 4/12
# 938/938 [==============================] - 104s 110ms/step - loss: 0.0340 - accuracy: 0.9892
# Epoch 5/12
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0282 - accuracy: 0.9911
# Epoch 6/12
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0230 - accuracy: 0.9926
# Epoch 7/12
# 938/938 [==============================] - 106s 113ms/step - loss: 0.0217 - accuracy: 0.9930
# Epoch 8/12
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0180 - accuracy: 0.9939
# Epoch 9/12
# 938/938 [==============================] - 105s 111ms/step - loss: 0.0171 - accuracy: 0.9942
# Epoch 10/12
# 938/938 [==============================] - 104s 111ms/step - loss: 0.0150 - accuracy: 0.9951
# Epoch 11/12
# 938/938 [==============================] - 103s 110ms/step - loss: 0.0132 - accuracy: 0.9957
# Epoch 12/12
# 938/938 [==============================] - 102s 109ms/step - loss: 0.0132 - accuracy: 0.9959

# %%
Test_loss2 = model2.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 5s 16ms/step - loss: 0.0240 - accuracy: 0.9938

# %%
print('Test loss:', Test_loss2[0])
print('Test accuracy:', Test_loss2[1])
# Out:
# Test loss: 0.02397640235722065
# Test accuracy: 0.9937999844551086

# %% [markdown]
# ## **784 - [24C5-P2] - [48C5-P2] - [64C5-P2] - 256 - 10**

# %%
# define cnn model1

model3 = Sequential()
model3.add(Conv2D(24, (5, 5), padding='same', activation='relu', input_shape=(28, 28, 1)))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.2))

model3.add(Conv2D(48, (5, 5), padding='same', activation='relu'))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.2))

model3.add(Conv2D(64, (5, 5), padding='same', activation='relu'))
model3.add(MaxPooling2D((2, 2)))
model3.add(Dropout(0.2))
  
model3.add(Flatten())                       # Talvez isso não seja necessário com o fetch_openml
model3.add(Dense(256, activation='relu'))
model3.add(Dropout(0.2))
model3.add(Dense(10, activation='softmax'))

# %%
# Compile the model
model3.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
model3.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 28, 28, 24)        624
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 14, 14, 24)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 14, 14, 24)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 48)        28848
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 48)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 7, 7, 48)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 7, 7, 64)          76864
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 3, 3, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 3, 3, 64)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               147712
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 256,618
# Trainable params: 256,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
history = model3.fit(X_train, y_train, batch_size=64, epochs=12)
# Out:
# Epoch 1/12
# 938/938 [==============================] - 148s 157ms/step - loss: 0.4815 - accuracy: 0.8384
# Epoch 2/12
# 938/938 [==============================] - 146s 156ms/step - loss: 0.0647 - accuracy: 0.9802
# Epoch 3/12
# 938/938 [==============================] - 152s 162ms/step - loss: 0.0468 - accuracy: 0.9855
# Epoch 4/12
# 938/938 [==============================] - 157s 168ms/step - loss: 0.0357 - accuracy: 0.9886
# Epoch 5/12
# 938/938 [==============================] - 157s 167ms/step - loss: 0.0308 - accuracy: 0.9910
# Epoch 6/12
# 938/938 [==============================] - 159s 170ms/step - loss: 0.0319 - accuracy: 0.9903
# Epoch 7/12
# 938/938 [==============================] - 154s 164ms/step - loss: 0.0240 - accuracy: 0.9926
# Epoch 8/12
# 938/938 [==============================] - 157s 167ms/step - loss: 0.0244 - accuracy: 0.9927
# Epoch 9/12
# 938/938 [==============================] - 154s 164ms/step - loss: 0.0199 - accuracy: 0.9934
# Epoch 10/12
# 938/938 [==============================] - 153s 163ms/step - loss: 0.0185 - accuracy: 0.9941
# Epoch 11/12
# 938/938 [==============================] - 146s 156ms/step - loss: 0.0171 - accuracy: 0.9946
# Epoch 12/12
# 938/938 [==============================] - 145s 155ms/step - loss: 0.0184 - accuracy: 0.9938

# %%
Test_loss3 = model3.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 6s 20ms/step - loss: 0.0260 - accuracy: 0.9936

# %%
print('Test loss:', Test_loss3[0])
print('Test accuracy:', Test_loss3[1])
# Out:
# Test loss: 0.025993548333644867
# Test accuracy: 0.9936000108718872
