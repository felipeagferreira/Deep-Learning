# %%
# Import modules
# Add modules as needed
from sklearn.datasets import fetch_openml
import numpy as np

# For windows laptops add following 2 lines:
# import matplotlib
# matplotlib.use('agg')

import matplotlib.pyplot as plt

import tensorflow.keras as keras

# %%
def load_data():
    # Import MNIST dataset from openml
    dataset = fetch_openml('mnist_784', version=1, data_home=None)

    # Data preparation
    raw_X = dataset['data']
    raw_Y = dataset['target']
    return raw_X, raw_Y

raw_X, raw_Y = load_data()

# %%
from keras.utils import to_categorical
number_of_classes = 10

def clean_data(raw_X, raw_Y):
    # TODO: clean and QA raw_X and raw_Y
    # DO NOT CHANGE THE INPUTS OR OUTPUTS TO THIS FUNCTION

    cleaned_X = raw_X.reshape(raw_X.shape[0], 28, 28, 1)
    cleaned_Y = to_categorical(raw_Y, 10)



    
    return cleaned_X, cleaned_Y

cleaned_X, cleaned_Y = clean_data(raw_X, raw_Y)

# %%
from sklearn.model_selection import train_test_split

def split_data(cleaned_X, cleaned_Y):
    # TODO: split the data
    # DO NOT CHANGE THE INPUTS OR OUTPUTS TO THIS FUNCTION

    X_train, X_test, Y_train, Y_test = train_test_split(cleaned_X, cleaned_Y, test_size=0.3)
    X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=2/7, train_size=5/7)


    
    return X_val, X_test, X_train, Y_val, Y_test, Y_train

X_val, X_test, X_train, Y_val, Y_test, Y_train = split_data(cleaned_X, cleaned_Y)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D

model = Sequential()                                # This is model3 of our last file
model.add(Conv2D(24, (5, 5), padding='same', activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(48, (5, 5), padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (5, 5), padding='same', activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))
  
model.add(Flatten())                       
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# # **Let's test many learning rates**

# %%
opt = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 82s 295ms/step - loss: 9.3028 - accuracy: 0.2620 - val_loss: 0.6336 - val_accuracy: 0.8441
# Epoch 2/12
# 274/274 [==============================] - 81s 295ms/step - loss: 1.0471 - accuracy: 0.6649 - val_loss: 0.2686 - val_accuracy: 0.9261
# Epoch 3/12
# 274/274 [==============================] - 80s 294ms/step - loss: 0.5717 - accuracy: 0.8175 - val_loss: 0.1830 - val_accuracy: 0.9459
# Epoch 4/12
# 274/274 [==============================] - 80s 293ms/step - loss: 0.4077 - accuracy: 0.8719 - val_loss: 0.1403 - val_accuracy: 0.9574
# Epoch 5/12
# 274/274 [==============================] - 80s 293ms/step - loss: 0.3059 - accuracy: 0.9050 - val_loss: 0.1178 - val_accuracy: 0.9638
# Epoch 6/12
# 274/274 [==============================] - 81s 294ms/step - loss: 0.2578 - accuracy: 0.9216 - val_loss: 0.1000 - val_accuracy: 0.9692
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 0.0593 - accuracy: 0.9813

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 0.05926387012004852
# Test accuracy: 0.981333315372467

# %%
opt = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 81s 294ms/step - loss: 0.1759 - accuracy: 0.9466 - val_loss: 0.0565 - val_accuracy: 0.9825
# Epoch 2/12
# 274/274 [==============================] - 80s 294ms/step - loss: 0.0967 - accuracy: 0.9712 - val_loss: 0.0497 - val_accuracy: 0.9849
# Epoch 3/12
# 274/274 [==============================] - 81s 294ms/step - loss: 0.0802 - accuracy: 0.9753 - val_loss: 0.0426 - val_accuracy: 0.9883
# Epoch 4/12
# 274/274 [==============================] - 81s 295ms/step - loss: 0.0625 - accuracy: 0.9814 - val_loss: 0.0400 - val_accuracy: 0.9883
# Epoch 5/12
# 274/274 [==============================] - 81s 294ms/step - loss: 0.0589 - accuracy: 0.9807 - val_loss: 0.0393 - val_accuracy: 0.9889
# Epoch 6/12
# 274/274 [==============================] - 81s 294ms/step - loss: 0.0549 - accuracy: 0.9823 - val_loss: 0.0387 - val_accuracy: 0.9888
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 0.0422 - accuracy: 0.9879

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 0.04223106801509857
# Test accuracy: 0.9878571629524231

# %%
opt = keras.optimizers.Adam(learning_rate=0.01)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 81s 294ms/step - loss: 0.5312 - accuracy: 0.8901 - val_loss: 0.2078 - val_accuracy: 0.9447
# Epoch 2/12
# 274/274 [==============================] - 80s 292ms/step - loss: 0.5467 - accuracy: 0.8761 - val_loss: 0.2586 - val_accuracy: 0.9413
# Epoch 3/12
# 274/274 [==============================] - 80s 292ms/step - loss: 0.6527 - accuracy: 0.8561 - val_loss: 0.9669 - val_accuracy: 0.7414
# Epoch 4/12
# 274/274 [==============================] - 80s 292ms/step - loss: 2.1354 - accuracy: 0.2544 - val_loss: 2.3030 - val_accuracy: 0.1106
# Epoch 5/12
# 274/274 [==============================] - 80s 293ms/step - loss: 2.3012 - accuracy: 0.1132 - val_loss: 2.3020 - val_accuracy: 0.1065
# Epoch 6/12
# 274/274 [==============================] - 80s 292ms/step - loss: 2.3009 - accuracy: 0.1104 - val_loss: 2.3023 - val_accuracy: 0.1106
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 2.3015 - accuracy: 0.1135

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 2.3014590740203857
# Test accuracy: 0.11352381110191345

# %%
opt = keras.optimizers.Adam(learning_rate=0.1)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 81s 292ms/step - loss: 2.3095 - accuracy: 0.1074 - val_loss: 2.3105 - val_accuracy: 0.0938
# Epoch 2/12
# 274/274 [==============================] - 80s 291ms/step - loss: 2.3073 - accuracy: 0.1035 - val_loss: 2.3129 - val_accuracy: 0.0959
# Epoch 3/12
# 274/274 [==============================] - 80s 290ms/step - loss: 2.3072 - accuracy: 0.1038 - val_loss: 2.3078 - val_accuracy: 0.1006
# Epoch 4/12
# 274/274 [==============================] - 80s 291ms/step - loss: 2.3099 - accuracy: 0.1029 - val_loss: 2.3070 - val_accuracy: 0.0938
# Epoch 5/12
# 274/274 [==============================] - 80s 291ms/step - loss: 2.3064 - accuracy: 0.1098 - val_loss: 2.3135 - val_accuracy: 0.1106
# Epoch 6/12
# 274/274 [==============================] - 80s 291ms/step - loss: 2.3075 - accuracy: 0.1033 - val_loss: 2.3026 - val_accuracy: 0.1106
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 2.3032 - accuracy: 0.1009

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 2.3032498359680176
# Test accuracy: 0.10090476274490356

# %%
opt = keras.optimizers.Adam(learning_rate=1)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 81s 292ms/step - loss: 2.3635 - accuracy: 0.1057 - val_loss: 2.3683 - val_accuracy: 0.0959
# Epoch 2/12
# 274/274 [==============================] - 80s 291ms/step - loss: 2.3412 - accuracy: 0.1068 - val_loss: 2.3457 - val_accuracy: 0.1106
# Epoch 3/12
# 274/274 [==============================] - 80s 291ms/step - loss: 2.3500 - accuracy: 0.1070 - val_loss: 2.3760 - val_accuracy: 0.1010
# Epoch 4/12
# 274/274 [==============================] - 80s 292ms/step - loss: 2.3427 - accuracy: 0.0982 - val_loss: 2.3727 - val_accuracy: 0.0986
# Epoch 5/12
# 274/274 [==============================] - 80s 291ms/step - loss: 2.3513 - accuracy: 0.1026 - val_loss: 2.3499 - val_accuracy: 0.1065
# Epoch 6/12
# 274/274 [==============================] - 80s 291ms/step - loss: 2.3506 - accuracy: 0.0965 - val_loss: 2.3911 - val_accuracy: 0.0959
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 2.3579 - accuracy: 0.1034

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 2.357912540435791
# Test accuracy: 0.10342857241630554

# %%
opt = keras.optimizers.Adam(learning_rate=10)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 81s 293ms/step - loss: 4.9935 - accuracy: 0.1037 - val_loss: 2.5485 - val_accuracy: 0.1065
# Epoch 2/12
# 274/274 [==============================] - 80s 291ms/step - loss: 2.6417 - accuracy: 0.0999 - val_loss: 2.6095 - val_accuracy: 0.0959
# Epoch 3/12
# 274/274 [==============================] - 80s 292ms/step - loss: 2.6991 - accuracy: 0.1020 - val_loss: 2.9809 - val_accuracy: 0.1065
# Epoch 4/12
# 274/274 [==============================] - 80s 292ms/step - loss: 2.8348 - accuracy: 0.0997 - val_loss: 2.7122 - val_accuracy: 0.0959
# Epoch 5/12
# 274/274 [==============================] - 80s 292ms/step - loss: 2.6722 - accuracy: 0.0991 - val_loss: 2.6546 - val_accuracy: 0.1010
# Epoch 6/12
# 274/274 [==============================] - 79s 289ms/step - loss: 2.6299 - accuracy: 0.1057 - val_loss: 2.4070 - val_accuracy: 0.1065
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 2.6846 - accuracy: 0.0984

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 2.6845974922180176
# Test accuracy: 0.09838095307350159

# %% [markdown]
# # As we can see, the best results came with 0.0001 < learning rate < 0.001.Let's test some values between these two, such as LR = (0.00028, 0.00046, 0.00064, 0.00082).

# %%
opt = keras.optimizers.Adam(learning_rate=0.00028)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 84s 306ms/step - loss: 8.5610 - accuracy: 0.3437 - val_loss: 0.2800 - val_accuracy: 0.9215
# Epoch 2/12
# 274/274 [==============================] - 83s 303ms/step - loss: 0.5136 - accuracy: 0.8384 - val_loss: 0.1533 - val_accuracy: 0.9537
# Epoch 3/12
# 274/274 [==============================] - 83s 302ms/step - loss: 0.3042 - accuracy: 0.9082 - val_loss: 0.1020 - val_accuracy: 0.9676
# Epoch 4/12
# 274/274 [==============================] - 82s 300ms/step - loss: 0.2242 - accuracy: 0.9304 - val_loss: 0.0834 - val_accuracy: 0.9734
# Epoch 5/12
# 274/274 [==============================] - 83s 304ms/step - loss: 0.1716 - accuracy: 0.9468 - val_loss: 0.0697 - val_accuracy: 0.9784
# Epoch 6/12
# 274/274 [==============================] - 82s 301ms/step - loss: 0.1485 - accuracy: 0.9548 - val_loss: 0.0594 - val_accuracy: 0.9819
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 0.0393 - accuracy: 0.9877

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 0.03926197066903114
# Test accuracy: 0.9877142906188965

# %%
opt = keras.optimizers.Adam(learning_rate=0.00046)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 84s 305ms/step - loss: 5.2735 - accuracy: 0.4753 - val_loss: 0.1563 - val_accuracy: 0.9501
# Epoch 2/12
# 274/274 [==============================] - 83s 302ms/step - loss: 0.2961 - accuracy: 0.9072 - val_loss: 0.0906 - val_accuracy: 0.9721
# Epoch 3/12
# 274/274 [==============================] - 83s 303ms/step - loss: 0.1908 - accuracy: 0.9420 - val_loss: 0.0667 - val_accuracy: 0.9795
# Epoch 4/12
# 274/274 [==============================] - 83s 302ms/step - loss: 0.1314 - accuracy: 0.9572 - val_loss: 0.0640 - val_accuracy: 0.9819
# Epoch 5/12
# 274/274 [==============================] - 83s 303ms/step - loss: 0.1093 - accuracy: 0.9657 - val_loss: 0.0506 - val_accuracy: 0.9855
# Epoch 6/12
# 274/274 [==============================] - 83s 302ms/step - loss: 0.0894 - accuracy: 0.9713 - val_loss: 0.0442 - val_accuracy: 0.9874
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 0.0328 - accuracy: 0.9895

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 0.03278431296348572
# Test accuracy: 0.989476203918457

# %%
opt = keras.optimizers.Adam(learning_rate=0.00064)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 83s 302ms/step - loss: 0.0665 - accuracy: 0.9791 - val_loss: 0.0412 - val_accuracy: 0.9869
# Epoch 2/12
# 274/274 [==============================] - 82s 301ms/step - loss: 0.0561 - accuracy: 0.9821 - val_loss: 0.0370 - val_accuracy: 0.9889
# Epoch 3/12
# 274/274 [==============================] - 82s 300ms/step - loss: 0.0508 - accuracy: 0.9841 - val_loss: 0.0374 - val_accuracy: 0.9892
# Epoch 4/12
# 274/274 [==============================] - 83s 302ms/step - loss: 0.0452 - accuracy: 0.9861 - val_loss: 0.0353 - val_accuracy: 0.9894
# Epoch 5/12
# 274/274 [==============================] - 82s 301ms/step - loss: 0.0412 - accuracy: 0.9864 - val_loss: 0.0370 - val_accuracy: 0.9898
# Epoch 6/12
# 274/274 [==============================] - 82s 301ms/step - loss: 0.0358 - accuracy: 0.9890 - val_loss: 0.0361 - val_accuracy: 0.9899
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 0.0320 - accuracy: 0.9909

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 0.03198697790503502
# Test accuracy: 0.9909047484397888

# %%
opt = keras.optimizers.Adam(learning_rate=0.00082)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 83s 300ms/step - loss: 0.0338 - accuracy: 0.9904 - val_loss: 0.0401 - val_accuracy: 0.9901
# Epoch 2/12
# 274/274 [==============================] - 82s 301ms/step - loss: 0.0334 - accuracy: 0.9899 - val_loss: 0.0416 - val_accuracy: 0.9900
# Epoch 3/12
# 274/274 [==============================] - 82s 301ms/step - loss: 0.0311 - accuracy: 0.9905 - val_loss: 0.0353 - val_accuracy: 0.9906
# Epoch 4/12
# 274/274 [==============================] - 82s 301ms/step - loss: 0.0300 - accuracy: 0.9909 - val_loss: 0.0392 - val_accuracy: 0.9892
# Epoch 5/12
# 274/274 [==============================] - 82s 300ms/step - loss: 0.0300 - accuracy: 0.9902 - val_loss: 0.0352 - val_accuracy: 0.9918
# Epoch 6/12
# 274/274 [==============================] - 83s 302ms/step - loss: 0.0338 - accuracy: 0.9905 - val_loss: 0.0468 - val_accuracy: 0.9871
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 0.0381 - accuracy: 0.9900

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 0.038142479956150055
# Test accuracy: 0.9900476336479187

# %%
opt = keras.optimizers.Adam(learning_rate=0.00095)
model.compile(optimizer= opt, loss="categorical_crossentropy", metrics=["accuracy"])

history = model.fit(X_train, Y_train, batch_size=128, epochs=12, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/12
# 274/274 [==============================] - 84s 304ms/step - loss: 0.0326 - accuracy: 0.9914 - val_loss: 0.0565 - val_accuracy: 0.9884
# Epoch 2/12
# 274/274 [==============================] - 83s 303ms/step - loss: 0.0386 - accuracy: 0.9890 - val_loss: 0.0462 - val_accuracy: 0.9902
# Epoch 3/12
# 274/274 [==============================] - 83s 301ms/step - loss: 0.0370 - accuracy: 0.9898 - val_loss: 0.0492 - val_accuracy: 0.9902
# Epoch 4/12
# 274/274 [==============================] - 84s 306ms/step - loss: 0.0280 - accuracy: 0.9922 - val_loss: 0.0452 - val_accuracy: 0.9898
# Epoch 5/12
# 274/274 [==============================] - 83s 303ms/step - loss: 0.0297 - accuracy: 0.9911 - val_loss: 0.0469 - val_accuracy: 0.9903
# Epoch 6/12
# 274/274 [==============================] - 83s 303ms/step - loss: 0.0317 - accuracy: 0.9912 - val_loss: 0.0444 - val_accuracy: 0.9891
# Epoch 7/12
# ...

# %%
Test_loss = model.evaluate(X_test, Y_test)
# Out:
# 657/657 [==============================] - 13s 20ms/step - loss: 0.0417 - accuracy: 0.9915

# %%
print('Test loss:', Test_loss[0])
print('Test accuracy:', Test_loss[1])
# Out:
# Test loss: 0.041700854897499084
# Test accuracy: 0.991523802280426
